# %%
import sklearn
# import shap

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# Import base classifiers
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier
from baselines import AdaFairClassifier
from imbens.ensemble import SMOTEBoostClassifier, SMOTEBaggingClassifier, RUSBoostClassifier, UnderBaggingClassifier, SelfPacedEnsembleClassifier
from fairlearn.postprocessing import ThresholdOptimizer
from fairens import FairAugEnsemble, FairEnsemble

# Set GPU for matrix computations
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device == 'cuda':
    torch.cuda.set_device(0)
    device_id = torch.cuda.current_device()
    print (f"Now using GPU #{device_id}:\n{torch.cuda.get_device_name(device_id)}")

# Import utilities
from data import FairDataset    # This is a custom class that we will use to load the datasets
from eval import evaluate_multi_split, verbose_print
from trainer import Trainer
from utils import seed_generator, dict_info, describe_data
# Out:
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'rpy2': FairAdapt will be unavailable. To install, run:
# pip install 'aif360[FairAdapt]'
# Now using GPU #0:
# Tesla V100-SXM2-32GB

# %% [markdown]
# # Load dataset

# %%
SEED = 42
n_splits = 5
i_split = 0

dataset_kwargs = {
    'y_col': 'label',
    'train_size': 0.6,
    'val_size': 0.2,
    'test_size': 0.2,
    'concat_train_val': True,
    'normalize': True,
    'random_state': 42,
}

# dataname = 'adult'
# s_attr = 'gender'
dataname = 'compas'
s_attr = 'sex'
data = FairDataset(
    dataname=dataname,
    csv_path=f'./data/{dataname}.csv',
    s_col=s_attr,
    x_with_s=True,
    **dataset_kwargs
)

data.describe()

(
    (X_train, y_train, s_train),
    (X_val, y_val, s_val),
    (X_test, y_test, s_test),
    (idx_train, idx_val, idx_test)
) = data.get_subgroup_split(i_split=i_split, random_state=SEED, n_splits=n_splits)

classes = np.unique(y_train)
n_feat = X_train.shape[1]
n_class = len(classes)
# Out:
# Dataset    : compas (5875, 12) load from ./data/compas.csv
# Sens/Res   : sex/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train data [#samples 4700 #features 11]:
# +-----+-------+-------+------------+
# |     |   y=0 |   y=1 |   pos_rate |
# +=====+=======+=======+============+
# | s=0 |   593 |   336 |     0.3617 |
# +-----+-------+-------+------------+
# | s=1 |  1917 |  1854 |     0.4916 |
# +-----+-------+-------+------------+
# test data [#samples 1175 #features 11]:
# +-----+-------+-------+------------+
# |     |   y=0 |   y=1 |   pos_rate |
# +=====+=======+=======+============+
# | s=0 |   148 |    84 |     0.3621 |
# +-----+-------+-------+------------+
# | s=1 |   480 |   463 |     0.491  |
# +-----+-------+-------+------------+

# %%
from baselines.lfr import LFRClassifier
from eval import evaluate

base_clf = LogisticRegression()

SEED = 42

clf = LFRClassifier(base_clf, random_state=SEED)
clf.fit(X_train, y_train, s_train)
evaluate(clf, X_test, y_test, s_test)
# Out:
# {'acc': 6.085106382978723e-01,
#  'bacc': 0.5937423602137394,
#  'ap': 0.5300762482890076,
#  'roc': 0.5937423602137394,
#  'f1': 0.5802267785026406,
#  'dp': 0.013845211540571167,
#  'eo': 0.090311986863711,
#  'ge': 0.27172077312816667,
#  'si': 0.06468085106382979,
#  'acc_grp': {0: 0.591, 1: 0.613},
#  'pos_rate_grp': {0: 0.263, 1: 0.277},
#  'g_adv': 1,
#  'acc_cls': {0: 0.813, 1: 0.374}}

# %%
pd.DataFrame(X_train, columns=data.feature_names)
# Out:
#       sex  MarriageStatus       age  race  juv_fel_count  juv_misd_count  \
# 0     1.0        0.166667  0.153846   1.0            0.0             0.0
# 1     1.0        0.000000  0.123077   0.0            0.0             0.0
# 2     1.0        0.000000  0.461538   1.0            0.1             0.0
# 3     1.0        0.000000  0.061538   0.0            0.0             0.0
# 4     0.0        0.000000  0.215385   0.0            0.0             0.0
# ...   ...             ...       ...   ...            ...             ...
# 3520  0.0        0.000000  0.061538   0.0            0.0             0.0
# 3521  1.0        0.000000  0.184615   0.0            0.0             0.0
# 3522  1.0        0.000000  0.092308   0.0            0.0             0.0
# 3523  1.0        0.000000  0.415385   0.0            0.0             0.0
# 3524  1.0        0.000000  0.184615   0.0            0.0             0.0
#
#       juv_other_count  priors_count  days_b_screening_arrest  \
# 0                 0.0      0.052632                 0.640381
# 1                 0.0      0.000000                 0.640721
# 2                 0.0      0.605263                 0.640381
# 3                 0.0      0.026316                 0.640381
# 4                 0.0      0.078947                 0.640381
# ...               ...           ...                      ...
# 3520              0.0      0.000000                 0.640721
# 3521              0.0      0.052632                 0.640381
# 3522              0.0      0.000000                 0.640721
# 3523              0.0      0.342105                 0.640381
# 3524              0.0      0.105263                 0.640381
#
#       c_days_from_compas  c_charge_degree
# 0               0.500053              1.0
# 1               0.500053              0.0
# 2               0.500053              1.0
# 3               0.500053              1.0
# 4               0.500053              0.0
# ...                  ...              ...
# 3520            0.500053              1.0
# 3521            0.500053              1.0
# 3522            0.500053              1.0
# 3523            0.500053              1.0
# 3524            0.500053              0.0
#
# [3525 rows x 11 columns]

# %%
# from aif360.sklearn.preprocessing import LearnedFairRepresentations
# from eval import evaluate

# lfr = LearnedFairRepresentations(
#     prot_attr=X_train[:, 0],
#     # prot_attr=s_train,
#     random_state=SEED
# )

# print (lfr.prot_attr)

# df_X_train = pd.DataFrame(X_train)

# lfr.fit(df_X_train, y_train, priv_group=1)

# X_train_edit = lfr.transform(pd.DataFrame(X_train))
# X_test_edit = lfr.transform(pd.DataFrame(X_test))

# clf = LogisticRegression(random_state=SEED)
# clf.fit(X_train_edit, y_train)

# evaluate(clf, X_test, y_test, s_test)

# %%
"""Load Datasets"""

dataset_kwargs = {
    'y_col': 'label',
    'train_size': 0.6,
    'val_size': 0.2,
    'test_size': 0.2,
    'concat_train_val': True,
    'normalize': True,
    'random_state': 42,
}

all_datasets = {
    'compas': ['sex', 'race'],
    'adult': ['gender', 'race'],
    'bank': ['age', 'marital=married'],
    'lsa': ['gender', 'race'],
    'lsa_unfair_gender_race': ['gender', 'race'],
    'meps': ['SEX', 'RACE'],
    'german': ['sex', 'foreign_worker', 'marital_status=single'],
}

"""
Create a dictionary of datasets: dataset_zoo
key: dataset name
value: FairDataset object
"""
dataset_zoo = {}
for dataname, s_attrs in all_datasets.items():
    for s_attr in s_attrs:
        dataset = FairDataset(
            dataname=dataname,
            csv_path=f'./data/{dataname}.csv',
            s_col=s_attr,
            **dataset_kwargs
        )
        dataset_zoo[dataset.fullname] = dataset

        # dataset.describe()
        dataset.brief()

# Print the information of the datasets and models
print(
    f"////// Dataset ZOO //////\n"
    f"{dict_info(dataset_zoo)}\n"
)

dataset_zoo_subset = {
    'compas_sex': dataset_zoo['compas_sex'],
    'compas_race': dataset_zoo['compas_race'],
}
# Out:
# Dataset    : compas (5875, 12) load from ./data/compas.csv
# Sens/Res   : sex/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 929, 1: 3771} | grp_pos_ratio: {0: 0.3617, 1: 0.4916}
# test       | size {0: 232, 1: 943} | grp_pos_ratio: {0: 0.3621, 1: 0.491}
#
# Dataset    : compas (5875, 12) load from ./data/compas.csv
# Sens/Res   : race/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 1878, 1: 2822} | grp_pos_ratio: {0: 0.3946, 1: 0.5135}
# test       | size {0: 469, 1: 706} | grp_pos_ratio: {0: 0.3945, 1: 0.5127}
#
# Dataset    : adult (45222, 99) load from ./data/adult.csv
# Sens/Res   : gender/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 11756, 1: 24421} | grp_pos_ratio: {0: 0.1136, 1: 0.3125}
# test       | size {0: 2939, 1: 6106} | grp_pos_ratio: {0: 0.1136, 1: 0.3125}
#
# Dataset    : adult (45222, 99) load from ./data/adult.csv
# Sens/Res   : race/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 5055, 1: 31122} | grp_pos_ratio: {0: 0.1585, 1: 0.2624}
# test       | size {0: 1264, 1: 7781} | grp_pos_ratio: {0: 0.1582, 1: 0.2623}
#
# Dataset    : bank (30488, 58) load from ./data/bank.csv
# Sens/Res   : age/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 23699, 1: 691} | grp_pos_ratio: {0: 0.1235, 1: 0.2301}
# test       | size {0: 5925, 1: 173} | grp_pos_ratio: {0: 0.1235, 1: 0.2312}
#
# Dataset    : bank (30488, 58) load from ./data/bank.csv
# Sens/Res   : marital=married/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 13994, 1: 10396} | grp_pos_ratio: {0: 0.1176, 1: 0.1387}
# test       | size {0: 3498, 1: 2600} | grp_pos_ratio: {0: 0.1175, 1: 0.1388}
#
# Dataset    : lsa (55448, 10) load from ./data/lsa.csv
# Sens/Res   : gender/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 24675, 1: 19683} | grp_pos_ratio: {0: 0.2778, 1: 0.281}
# test       | size {0: 6169, 1: 4921} | grp_pos_ratio: {0: 0.2778, 1: 0.281}
#
# Dataset    : lsa (55448, 10) load from ./data/lsa.csv
# Sens/Res   : race/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 11567, 1: 32791} | grp_pos_ratio: {0: 0.2308, 1: 0.2963}
# test       | size {0: 2892, 1: 8198} | grp_pos_ratio: {0: 0.231, 1: 0.2963}
#
# Dataset    : lsa_unfair_gender_race (49900, 10) load from ./data/lsa_unfair_gender_race.csv
# Sens/Res   : gender/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 20946, 1: 18974} | grp_pos_ratio: {0: 0.1492, 1: 0.2541}
# test       | size {0: 5237, 1: 4743} | grp_pos_ratio: {0: 0.1493, 1: 0.2541}
#
# Dataset    : lsa_unfair_gender_race (49900, 10) load from ./data/lsa_unfair_gender_race.csv
# Sens/Res   : race/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 9884, 1: 30036} | grp_pos_ratio: {0: 0.0999, 1: 0.2317}
# test       | size {0: 2471, 1: 7509} | grp_pos_ratio: {0: 0.1, 1: 0.2317}
#
# Dataset    : meps (15839, 126) load from ./data/meps.csv
# Sens/Res   : SEX/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 6067, 1: 6604} | grp_pos_ratio: {0: 0.1327, 1: 0.2078}
# test       | size {0: 1517, 1: 1651} | grp_pos_ratio: {0: 0.1325, 1: 0.2078}
#
# Dataset    : meps (15839, 126) load from ./data/meps.csv
# Sens/Res   : RACE/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 8144, 1: 4527} | grp_pos_ratio: {0: 0.1251, 1: 0.2558}
# test       | size {0: 2036, 1: 1132} | grp_pos_ratio: {0: 0.1252, 1: 0.2553}
#
# Dataset    : german (1000, 55) load from ./data/german.csv
# Sens/Res   : sex/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 248, 1: 552} | grp_pos_ratio: {0: 0.6492, 1: 0.7228}
# test       | size {0: 62, 1: 138} | grp_pos_ratio: {0: 0.6452, 1: 0.7246}
#
# Dataset    : german (1000, 55) load from ./data/german.csv
# Sens/Res   : foreign_worker/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 771, 1: 29} | grp_pos_ratio: {0: 0.6926, 1: 0.8966}
# test       | size {0: 192, 1: 8} | grp_pos_ratio: {0: 0.6927, 1: 0.875}
#
# Dataset    : german (1000, 55) load from ./data/german.csv
# Sens/Res   : marital_status=single/label
# Split      : train/test = 0.8/0.2, random_state = 42, x_with_s = True
# train      | size {0: 361, 1: 439} | grp_pos_ratio: {0: 0.6593, 1: 0.7335}
# test       | size {0: 91, 1: 109} | grp_pos_ratio: {0: 0.6593, 1: 0.7339}
#
# ////// Dataset ZOO //////
# compas_sex: <data.FairDataset object at 0x7f29d26340d0>
# compas_race: <data.FairDataset object at 0x7f29d26333d0>
# adult_gender: <data.FairDataset object at 0x7f29d2633d00>
# adult_race: <data.FairDataset object at 0x7f2a083370a0>
# bank_age: <data.FairDataset object at 0x7f29d3ac76a0>
# bank_marital=married: <data.FairDataset object at 0x7f29d3ac7d30>
# lsa_gender: <data.FairDataset object at 0x7f29d448fe50>
# lsa_race: <data.FairDataset object at 0x7f2a08336880>
# lsa_unfair_gender_race_gender: <data.FairDataset object at 0x7f2a083374c0>
# lsa_unfair_gender_race_race: <data.FairDataset object at 0x7f2a08337d00>
# meps_SEX: <data.FairDataset object at 0x7f29d25fcd30>
# meps_RACE: <data.FairDataset object at 0x7f29d25fcdc0>
# german_sex: <data.FairDataset object at 0x7f29d25fc400>
# german_foreign_worker: <data.FairDataset object at 0x7f29d25fc3a0>
# german_marital_status=single: <data.FairDataset object at 0x7f29d25fc460>

# %%
from baselines import ReweightClassifier, AdaFairClassifier, ReductionClassifier, ThresholdClassifier, MimicClassifier
import tqdm
from eval import evaluate


def run_baseline_exp(dataset_zoo, base_model_zoo, model_zoo, n_splits=5, n_runs=1, random_state=42, verbose=False):
    """
    Run baseline experiment with different base models and different datasets.
    """
    print(
        f"////// Baseline Experiment //////\n"
        f"Base Model Zoo: {list(base_model_zoo.keys())}\n"
        f"Model Zoo: {list(model_zoo.keys())}\n"
        f"Dataset Zoo: {list(dataset_zoo.keys())}\n"
        f"n_splits: {n_splits}\n"
        f"n_runs: {n_runs}\n"
        f"random_state: {random_state}\n"
    )

    all_res = []

    for data_name, data in dataset_zoo.items():

        for base_model_name, base_model in base_model_zoo.items():
            
            for model_name, (model, model_kwargs) in model_zoo.items():

                for i_run in range(n_runs):

                    print (f"Data: {data_name} | Run: {i_run} | Base: {base_model_name} | Model: {model_name}")
                    rand_seed = random_state + i_run

                    base_model = base_model.set_params(random_state=rand_seed)
                    
                    for i_split in tqdm.tqdm(range(n_splits), disable=verbose):
                        
                        # get the i-th split of a n-fold cross validation
                        (
                            (X_train, y_train, s_train),
                            (X_val, y_val, s_val),
                            (X_test, y_test, s_test),
                            (idx_train, idx_val, idx_test)
                        ) = data.get_subgroup_split(
                            i_split=i_split, 
                            random_state=rand_seed,
                            n_splits=n_splits
                        )

                        clf = model(
                            estimator=base_model,
                            random_state=rand_seed,
                            **model_kwargs,
                        )
                        try:
                            clf.fit(X_train, y_train)
                        except Exception as e:
                            # print (f"Error: {e}")
                            clf.fit(X_train, y_train, sensitive_features=s_train)
                        
                        res = evaluate(clf, X_test, y_test, s_test)

                        all_res.append({
                            **res,
                            'method': model_name,
                            'n_edit': 0,
                            'dataset': data_name,
                            'base_model': base_model_name,
                            'i_run': i_run,
                        })
                        if verbose:
                            res_vis = res.copy()
                            for k, v in res_vis.items():
                                if isinstance(v, float):
                                    res_vis[k] = np.round(v*100, 2)
                            print (f"Split: {i_split} | {res_vis}")

    df_res = pd.DataFrame(all_res)
    df_res['n_edit'] = 0
    
    return df_res

ensemble_kwargs = {
    'n_estimators': 10,
    # 'random_state': 42,
}

base_model_zoo = {
    'LR': LogisticRegression(),
    # 'KN': KNeighborsClassifier(n_neighbors=5),
    # 'DT': DecisionTreeClassifier(max_depth=10),
    # 'MLP': MLPClassifier(hidden_layer_sizes=(8), max_iter=50),
    # 'ADA': AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=None), n_estimators=5),
    # 'BAG': BaggingClassifier(estimator=DecisionTreeClassifier(max_depth=None), n_estimators=5),
}

model_zoo = {
    'ERM': (MimicClassifier, {}),
    'ThrDP': (ThresholdClassifier, {'constraints': 'demographic_parity'}),
    'ThrEO': (ThresholdClassifier, {'constraints': 'equalized_odds'}),
    'RedDP': (ReductionClassifier, {'constraints': 'DemographicParity'}),
    'RedEO': (ReductionClassifier, {'constraints': 'EqualizedOdds'}),
    'RW': (ReweightClassifier, {}),
    'LFR': (LFRClassifier, {}),
    'AdaF1': (AdaFairClassifier, {'saIndex': 0, 'saValue': 0, 'CSB': 'CSB1', **ensemble_kwargs}),
    # 'AdaF2': (AdaFairClassifier, {'saIndex': 0, 'saValue': 0, 'CSB': 'CSB2', **ensemble_kwargs}),
}

seed = 42
n_runs = 1
n_split = 5

df_res = run_baseline_exp(dataset_zoo, base_model_zoo, model_zoo, n_splits=n_split, n_runs=n_runs, random_state=seed, verbose=False)
# Out:
# ////// Baseline Experiment //////
# Base Model Zoo: ['LR']
# Model Zoo: ['ERM', 'ThrDP', 'ThrEO', 'RedDP', 'RedEO', 'RW', 'LFR', 'AdaF1']
# Dataset Zoo: ['compas_sex', 'compas_race', 'adult_gender', 'adult_race', 'bank_age', 'bank_marital=married', 'lsa_gender', 'lsa_race', 'lsa_unfair_gender_race_gender', 'lsa_unfair_gender_race_race', 'meps_SEX', 'meps_RACE', 'german_sex', 'german_foreign_worker', 'german_marital_status=single']
# n_splits: 5
# n_runs: 1
# random_state: 42
#
# Data: compas_sex | Run: 0 | Base: LR | Model: ERM
# Split: 0 | {'acc': 69.45, 'bacc': 69.05, 'ap': 60.62, 'roc': 69.05, 'f1': 69.1, 'dp': 36.15, 'eo': 43.64, 'ge': 16.44, 'si': 21.45, 'acc_grp': {0: 0.69, 1: 0.696}, 'pos_rate_grp': {0: 0.138, 1: 0.499}, 'g_adv': 1, 'acc_cls': {0: 0.75, 1: 0.631}}
# Split: 1 | {'acc': 67.23, 'bacc': 66.77, 'ap': 58.55, 'roc': 66.77, 'f1': 66.8, 'dp': 37.24, 'eo': 39.76, 'ge': 17.91, 'si': 24.26, 'acc_grp': {0: 0.707, 1: 0.664}, 'pos_rate_grp': {0: 0.121, 1: 0.493}, 'g_adv': 1, 'acc_cls': {0: 0.737, 1: 0.599}}
# Split: 2 | {'acc': 71.06, 'bacc': 70.5, 'ap': 62.29, 'roc': 70.5, 'f1': 70.56, 'dp': 34.26, 'eo': 35.68, 'ge': 16.21, 'si': 23.15, 'acc_grp': {0: 0.741, 1: 0.703}, 'pos_rate_grp': {0: 0.129, 1: 0.472}, 'g_adv': 1, 'acc_cls': {0: 0.787, 1: 0.623}}
# Split: 3 | {'acc': 66.81, 'bacc': 66.31, 'ap': 58.07, 'roc': 66.31, 'f1': 66.34, 'dp': 33.06, 'eo': 33.19, 'ge': 18.23, 'si': 21.02, 'acc_grp': {0: 0.711, 1: 0.657}, 'pos_rate_grp': {0: 0.151, 1: 0.481}, 'g_adv': 1, 'acc_cls': {0: 0.736, 1: 0.59}}
# Split: 4 | {'acc': 65.11, 'bacc': 64.59, 'ap': 56.54, 'roc': 64.59, 'f1': 64.6, 'dp': 35.64, 'eo': 44.88, 'ge': 19.23, 'si': 19.49, 'acc_grp': {0: 0.648, 1: 0.652}, 'pos_rate_grp': {0: 0.129, 1: 0.485}, 'g_adv': 1, 'acc_cls': {0: 0.721, 1: 0.57}}
# Data: compas_sex | Run: 0 | Base: LR | Model: ThrDP
# Split: 0 | {'acc': 66.21, 'bacc': 66.27, 'ap': 57.56, 'roc': 66.27, 'f1': 66.17, 'dp': 0.81, 'eo': 17.45, 'ge': 15.83, 'si': 20.0, 'acc_grp': {0: 0.526, 1: 0.696}, 'pos_rate_grp': {0: 0.491, 1: 0.499}, 'g_adv': 1, 'acc_cls': {0: 0.654, 1: 0.672}}
# Split: 1 | {'acc': 64.94, 'bacc': 64.94, 'ap': 56.49, 'roc': 64.94, 'f1': 64.87, 'dp': 1.47, 'eo': 8.02, 'ge': 16.7, 'si': 22.21, 'acc_grp': {0: 0.591, 1: 0.664}, 'pos_rate_grp': {0: 0.478, 1: 0.493}, 'g_adv': 1, 'acc_cls': {0: 0.649, 1: 0.65}}
# Split: 2 | {'acc': 67.74, 'bacc': 67.75, 'ap': 58.82, 'roc': 67.75, 'f1': 67.68, 'dp': 8.41, 'eo': 21.36, 'ge': 15.39, 'si': 20.51, 'acc_grp': {0: 0.573, 1: 0.703}, 'pos_rate_grp': {0: 0.556, 1: 0.472}, 'g_adv': 0, 'acc_cls': {0: 0.677, 1: 0.678}}
# Split: 3 | {'acc': 64.17, 'bacc': 64.16, 'ap': 55.78, 'roc': 64.16, 'f1': 64.09, 'dp': 3.58, 'eo': 12.56, 'ge': 17.09, 'si': 19.49, 'acc_grp': {0: 0.578, 1: 0.657}, 'pos_rate_grp': {0: 0.517, 1: 0.481}, 'g_adv': 0, 'acc_cls': {0: 0.643, 1: 0.64}}
# Split: 4 | {'acc': 62.47, 'bacc': 62.38, 'ap': 54.42, 'roc': 62.38, 'f1': 62.35, 'dp': 3.45, 'eo': 18.69, 'ge': 18.29, 'si': 17.79, 'acc_grp': {0: 0.515, 1: 0.652}, 'pos_rate_grp': {0: 0.451, 1: 0.485}, 'g_adv': 1, 'acc_cls': {0: 0.637, 1: 0.611}}
# Data: compas_sex | Run: 0 | Base: LR | Model: ThrEO
# Split: 0 | {'acc': 64.34, 'bacc': 63.1, 'ap': 56.13, 'roc': 63.1, 'f1': 62.41, 'dp': 3.37, 'eo': 10.62, 'ge': 23.43, 'si': 13.87, 'acc_grp': {0: 0.616, 1: 0.65}, 'pos_rate_grp': {0: 0.28, 1: 0.314}, 'g_adv': 1, 'acc_cls': {0: 0.815, 1: 0.447}}
# Split: 1 | {'acc': 59.91, 'bacc': 58.38, 'ap': 52.21, 'roc': 58.38, 'f1': 56.83, 'dp': 3.65, 'eo': 3.41, 'ge': 28.19, 'si': 15.15, 'acc_grp': {0: 0.668, 1: 0.582}, 'pos_rate_grp': {0: 0.237, 1: 0.274}, 'g_adv': 1, 'acc_cls': {0: 0.812, 1: 0.356}}
# Split: 2 | {'acc': 59.66, 'bacc': 57.55, 'ap': 51.92, 'roc': 57.55, 'f1': 54.16, 'dp': 5.03, 'eo': 13.26, 'ge': 31.26, 'si': 11.49, 'acc_grp': {0: 0.685, 1: 0.575}, 'pos_rate_grp': {0: 0.228, 1: 0.178}, 'g_adv': 0, 'acc_cls': {0: 0.882, 1: 0.269}}
# Split: 3 | {'acc': 59.57, 'bacc': 57.61, 'ap': 51.81, 'roc': 57.61, 'f1': 54.8, 'dp': 3.45, 'eo': 12.07, 'ge': 30.6, 'si': 10.13, 'acc_grp': {0: 0.685, 1: 0.574}, 'pos_rate_grp': {0: 0.237, 1: 0.203}, 'g_adv': 0, 'acc_cls': {0: 0.861, 1: 0.291}}
# Split: 4 | {'acc': 61.45, 'bacc': 59.91, 'ap': 53.42, 'roc': 59.91, 'f1': 58.56, 'dp': 8.06, 'eo': 13.55, 'ge': 26.81, 'si': 11.83, 'acc_grp': {0: 0.622, 1: 0.613}, 'pos_rate_grp': {0: 0.206, 1: 0.287}, 'g_adv': 1, 'acc_cls': {0: 0.822, 1: 0.377}}
# Data: compas_sex | Run: 0 | Base: LR | Model: RedDP
# Split: 0 | {'acc': 67.06, 'bacc': 66.99, 'ap': 58.31, 'roc': 66.99, 'f1': 66.96, 'dp': 13.84, 'eo': 21.56, 'ge': 16.1, 'si': 0.0, 'acc_grp': {0: 0.616, 1: 0.684}, 'pos_rate_grp': {0: 0.366, 1: 0.505}, 'g_adv': 1, 'acc_cls': {0: 0.681, 1: 0.659}}
# Split: 1 | {'acc': 66.89, 'bacc': 66.51, 'ap': 58.21, 'roc': 66.51, 'f1': 66.54, 'dp': 14.02, 'eo': 11.31, 'ge': 17.71, 'si': 0.0, 'acc_grp': {0: 0.69, 1: 0.664}, 'pos_rate_grp': {0: 0.319, 1: 0.459}, 'g_adv': 1, 'acc_cls': {0: 0.722, 1: 0.608}}
# Split: 2 | {'acc': 69.53, 'bacc': 69.3, 'ap': 60.53, 'roc': 69.3, 'f1': 69.33, 'dp': 10.87, 'eo': 6.66, 'ge': 15.6, 'si': 0.0, 'acc_grp': {0: 0.72, 1: 0.689}, 'pos_rate_grp': {0: 0.366, 1: 0.475}, 'g_adv': 1, 'acc_cls': {0: 0.726, 1: 0.66}}
# Split: 3 | {'acc': 66.38, 'bacc': 66.18, 'ap': 57.64, 'roc': 66.18, 'f1': 66.19, 'dp': 9.46, 'eo': 5.94, 'ge': 17.01, 'si': 0.0, 'acc_grp': {0: 0.685, 1: 0.659}, 'pos_rate_grp': {0: 0.384, 1: 0.478}, 'g_adv': 1, 'acc_cls': {0: 0.691, 1: 0.633}}
# Split: 4 | {'acc': 64.51, 'bacc': 64.36, 'ap': 56.04, 'roc': 64.36, 'f1': 64.35, 'dp': 17.7, 'eo': 22.8, 'ge': 17.65, 'si': 0.0, 'acc_grp': {0: 0.622, 1: 0.651}, 'pos_rate_grp': {0: 0.326, 1: 0.503}, 'g_adv': 1, 'acc_cls': {0: 0.666, 1: 0.622}}
# Data: compas_sex | Run: 0 | Base: LR | Model: RedEO
# Split: 0 | {'acc': 64.6, 'bacc': 65.1, 'ap': 56.3, 'roc': 65.1, 'f1': 64.56, 'dp': 10.26, 'eo': 18.29, 'ge': 14.26, 'si': 0.0, 'acc_grp': {0: 0.569, 1: 0.665}, 'pos_rate_grp': {0: 0.483, 1: 0.585}, 'g_adv': 1, 'acc_cls': {0: 0.576, 1: 0.726}}
# Split: 1 | {'acc': 67.06, 'bacc': 66.69, 'ap': 58.36, 'roc': 66.69, 'f1': 66.73, 'dp': 15.31, 'eo': 11.56, 'ge': 17.56, 'si': 0.0, 'acc_grp': {0: 0.707, 1: 0.662}, 'pos_rate_grp': {0: 0.31, 1: 0.463}, 'g_adv': 1, 'acc_cls': {0: 0.722, 1: 0.611}}
# Split: 2 | {'acc': 68.26, 'bacc': 67.98, 'ap': 59.34, 'roc': 67.98, 'f1': 68.01, 'dp': 9.59, 'eo': 7.49, 'ge': 16.44, 'si': 0.0, 'acc_grp': {0: 0.724, 1: 0.672}, 'pos_rate_grp': {0: 0.371, 1: 0.467}, 'g_adv': 1, 'acc_cls': {0: 0.72, 1: 0.64}}
# Split: 3 | {'acc': 64.51, 'bacc': 64.5, 'ap': 56.06, 'roc': 64.5, 'f1': 64.44, 'dp': 6.09, 'eo': 3.82, 'ge': 16.93, 'si': 0.0, 'acc_grp': {0: 0.664, 1: 0.641}, 'pos_rate_grp': {0: 0.44, 1: 0.501}, 'g_adv': 1, 'acc_cls': {0: 0.646, 1: 0.644}}
# Split: 4 | {'acc': 64.0, 'bacc': 63.73, 'ap': 55.61, 'roc': 63.73, 'f1': 63.75, 'dp': 13.44, 'eo': 14.37, 'ge': 18.52, 'si': 0.0, 'acc_grp': {0: 0.639, 1: 0.64}, 'pos_rate_grp': {0: 0.343, 1: 0.478}, 'g_adv': 1, 'acc_cls': {0: 0.677, 1: 0.598}}
# Data: compas_sex | Run: 0 | Base: LR | Model: RW
# Split: 0 | {'acc': 69.53, 'bacc': 68.57, 'ap': 61.2, 'roc': 68.57, 'f1': 68.39, 'dp': 31.56, 'eo': 42.92, 'ge': 18.81, 'si': 17.87, 'acc_grp': {0: 0.677, 1: 0.7}, 'pos_rate_grp': {0: 0.091, 1: 0.406}, 'g_adv': 1, 'acc_cls': {0: 0.829, 1: 0.542}}
# Split: 1 | {'acc': 68.0, 'bacc': 66.97, 'ap': 59.65, 'roc': 66.97, 'f1': 66.69, 'dp': 34.26, 'eo': 41.31, 'ge': 20.05, 'si': 21.87, 'acc_grp': {0: 0.698, 1: 0.676}, 'pos_rate_grp': {0: 0.06, 1: 0.403}, 'g_adv': 1, 'acc_cls': {0: 0.823, 1: 0.516}}
# Split: 2 | {'acc': 69.02, 'bacc': 67.77, 'ap': 60.89, 'roc': 67.77, 'f1': 67.31, 'dp': 28.4, 'eo': 34.62, 'ge': 20.14, 'si': 18.04, 'acc_grp': {0: 0.707, 1: 0.686}, 'pos_rate_grp': {0: 0.078, 1: 0.362}, 'g_adv': 1, 'acc_cls': {0: 0.86, 1: 0.495}}
# Split: 3 | {'acc': 66.3, 'bacc': 65.24, 'ap': 57.81, 'roc': 65.24, 'f1': 64.92, 'dp': 29.0, 'eo': 33.65, 'ge': 21.13, 'si': 17.87, 'acc_grp': {0: 0.69, 1: 0.656}, 'pos_rate_grp': {0: 0.103, 1: 0.393}, 'g_adv': 1, 'acc_cls': {0: 0.806, 1: 0.499}}
# Split: 4 | {'acc': 64.6, 'bacc': 63.52, 'ap': 56.19, 'roc': 63.52, 'f1': 63.12, 'dp': 31.55, 'eo': 43.93, 'ge': 22.31, 'si': 18.38, 'acc_grp': {0: 0.635, 1: 0.649}, 'pos_rate_grp': {0: 0.082, 1: 0.397}, 'g_adv': 1, 'acc_cls': {0: 0.791, 1: 0.479}}
# Data: compas_sex | Run: 0 | Base: LR | Model: LFR
# Split: 0 | {'acc': 6.085e+01, 'bacc': 59.37, 'ap': 53.01, 'roc': 59.37, 'f1': 58.02, 'dp': 1.38, 'eo': 9.03, 'ge': 27.17, 'si': 6.47, 'acc_grp': {0: 0.591, 1: 0.613}, 'pos_rate_grp': {0: 0.263, 1: 0.277}, 'g_adv': 1, 'acc_cls': {0: 0.813, 1: 0.374}}
# Split: 1 | {'acc': 6.051e+01, 'bacc': 58.91, 'ap': 52.72, 'roc': 58.91, 'f1': 57.2, 'dp': 2.56, 'eo': 9.24, 'ge': 28.14, 'si': 7.83, 'acc_grp': {0: 0.672, 1: 0.589}, 'pos_rate_grp': {0: 0.276, 1: 0.25}, 'g_adv': 0, 'acc_cls': {0: 0.828, 1: 0.35}}
# Split: 2 | {'acc': 6.17e+01, 'bacc': 59.73, 'ap': 53.83, 'roc': 59.73, 'f1': 57.1, 'dp': 1.06, 'eo': 2.66, 'ge': 28.76, 'si': 9.11, 'acc_grp': {0: 0.681, 1: 0.601}, 'pos_rate_grp': {0: 0.198, 1: 0.209}, 'g_adv': 1, 'acc_cls': {0: 0.884, 1: 0.311}}
# Split: 3 | {'acc': 6.17e+01, 'bacc': 59.74, 'ap': 53.82, 'roc': 59.74, 'f1': 57.15, 'dp': 3.56, 'eo': 8.07, 'ge': 28.71, 'si': 11.4, 'acc_grp': {0: 0.677, 1: 0.602}, 'pos_rate_grp': {0: 0.237, 1: 0.201}, 'g_adv': 0, 'acc_cls': {0: 0.882, 1: 0.313}}
# Split: 4 | {'acc': 5.932e+01, 'bacc': 57.73, 'ap': 51.6, 'roc': 57.73, 'f1': 56.13, 'dp': 2.5, 'eo': 3.06, 'ge': 28.69, 'si': 7.91, 'acc_grp': {0: 0.627, 1: 0.585}, 'pos_rate_grp': {0: 0.245, 1: 0.27}, 'g_adv': 1, 'acc_cls': {0: 0.807, 1: 0.347}}
# Data: compas_sex | Run: 0 | Base: LR | Model: AdaF1
# Split: 0 | {'acc': 6.374e+01, 'bacc': 63.8, 'ap': 55.53, 'roc': 63.8, 'f1': 63.7, 'dp': 2.53, 'eo': 3.75, 'ge': 16.96, 'si': 38.04, 'acc_grp': {0: 0.608, 1: 0.645}, 'pos_rate_grp': {0: 0.478, 1: 0.504}, 'g_adv': 1, 'acc_cls': {0: 0.63, 1: 0.646}}
# Split: 1 | {'acc': 6.204e+01, 'bacc': 61.56, 'ap': 54.08, 'roc': 61.56, 'f1': 61.55, 'dp': 4.05, 'eo': 1.12, 'ge': 20.74, 'si': 38.38, 'acc_grp': {0: 0.638, 1: 0.616}, 'pos_rate_grp': {0: 0.388, 1: 0.428}, 'g_adv': 1, 'acc_cls': {0: 0.687, 1: 0.544}}
# Split: 2 | {'acc': 6.255e+01, 'bacc': 62.99, 'ap': 54.64, 'roc': 62.99, 'f1': 62.54, 'dp': 2.97, 'eo': 2.53, 'ge': 15.47, 'si': 49.28, 'acc_grp': {0: 0.625, 1: 0.626}, 'pos_rate_grp': {0: 0.53, 1: 0.56}, 'g_adv': 1, 'acc_cls': {0: 0.567, 1: 0.693}}
# Split: 3 | {'acc': 6.009e+01, 'bacc': 60.29, 'ap': 52.75, 'roc': 60.29, 'f1': 60.08, 'dp': 31.28, 'eo': 32.54, 'ge': 17.72, 'si': 21.79, 'acc_grp': {0: 0.625, 1: 0.595}, 'pos_rate_grp': {0: 0.272, 1: 0.584}, 'g_adv': 1, 'acc_cls': {0: 0.573, 1: 0.633}}
# Split: 4 | {'acc': 6.128e+01, 'bacc': 60.89, 'ap': 53.42, 'roc': 60.89, 'f1': 60.9, 'dp': 7.21, 'eo': 11.59, 'ge': 20.52, 'si': 37.45, 'acc_grp': {0: 0.592, 1: 0.618}, 'pos_rate_grp': {0: 0.494, 1: 0.421}, 'g_adv': 0, 'acc_cls': {0: 0.666, 1: 0.552}}
# Data: compas_race | Run: 0 | Base: LR | Model: ERM
# Split: 0 | {'acc': 65.96, 'bacc': 65.45, 'ap': 57.39, 'roc': 65.45, 'f1': 65.46, 'dp': 33.83, 'eo': 34.67, 'ge': 18.82, 'si': 7.06, 'acc_grp': {0: 0.67, 1: 0.652}, 'pos_rate_grp': {0: 0.211, 1: 0.549}, 'g_adv': 1, 'acc_cls': {0: 0.73, 1: 0.578}}
# Split: 1 | {'acc': 65.53, 'bacc': 65.18, 'ap': 56.9, 'roc': 65.18, 'f1': 65.22, 'dp': 26.6, 'eo': 27.99, 'ge': 18.14, 'si': 3.49, 'acc_grp': {0: 0.655, 1: 0.656}, 'pos_rate_grp': {0: 0.279, 1: 0.545}, 'g_adv': 1, 'acc_cls': {0: 0.702, 1: 0.601}}
# Split: 2 | {'acc': 70.55, 'bacc': 69.93, 'ap': 61.81, 'roc': 69.93, 'f1': 69.98, 'dp': 25.76, 'eo': 29.1, 'ge': 16.73, 'si': 2.98, 'acc_grp': {0: 0.693, 1: 0.714}, 'pos_rate_grp': {0: 0.241, 1: 0.499}, 'g_adv': 1, 'acc_cls': {0: 0.79, 1: 0.609}}
# Split: 3 | {'acc': 69.87, 'bacc': 69.41, 'ap': 60.99, 'roc': 69.41, 'f1': 69.47, 'dp': 30.92, 'eo': 34.31, 'ge': 16.43, 'si': 7.15, 'acc_grp': {0: 0.687, 1: 0.706}, 'pos_rate_grp': {0: 0.234, 1: 0.543}, 'g_adv': 1, 'acc_cls': {0: 0.761, 1: 0.627}}
# Split: 4 | {'acc': 67.06, 'bacc': 66.51, 'ap': 58.42, 'roc': 66.51, 'f1': 66.52, 'dp': 27.46, 'eo': 28.31, 'ge': 18.45, 'si': 6.89, 'acc_grp': {0: 0.676, 1: 0.667}, 'pos_rate_grp': {0: 0.241, 1: 0.516}, 'g_adv': 1, 'acc_cls': {0: 0.748, 1: 0.582}}
# Data: compas_race | Run: 0 | Base: LR | Model: ThrDP
# Split: 0 | {'acc': 60.26, 'bacc': 60.55, 'ap': 52.99, 'roc': 60.55, 'f1': 60.25, 'dp': 2.62, 'eo': 12.89, 'ge': 17.12, 'si': 5.96, 'acc_grp': {0: 0.53, 1: 0.651}, 'pos_rate_grp': {0: 0.521, 1: 0.548}, 'g_adv': 1, 'acc_cls': {0: 0.561, 1: 0.65}}
# Split: 1 | {'acc': 60.51, 'bacc': 60.85, 'ap': 53.11, 'roc': 60.85, 'f1': 60.51, 'dp': 0.8, 'eo': 12.04, 'ge': 16.78, 'si': 2.98, 'acc_grp': {0: 0.529, 1: 0.656}, 'pos_rate_grp': {0: 0.537, 1: 0.545}, 'g_adv': 1, 'acc_cls': {0: 0.559, 1: 0.658}}
# Split: 2 | {'acc': 65.53, 'bacc': 65.67, 'ap': 56.92, 'roc': 65.67, 'f1': 65.51, 'dp': 2.59, 'eo': 18.57, 'ge': 15.74, 'si': 2.64, 'acc_grp': {0: 0.567, 1: 0.714}, 'pos_rate_grp': {0: 0.525, 1: 0.499}, 'g_adv': 0, 'acc_cls': {0: 0.637, 1: 0.676}}
# Split: 3 | {'acc': 65.02, 'bacc': 65.47, 'ap': 56.55, 'roc': 65.47, 'f1': 65.01, 'dp': 2.91, 'eo': 17.29, 'ge': 14.4, 'si': 5.7, 'acc_grp': {0: 0.566, 1: 0.706}, 'pos_rate_grp': {0: 0.572, 1: 0.543}, 'g_adv': 0, 'acc_cls': {0: 0.589, 1: 0.72}}
# Split: 4 | {'acc': 61.79, 'bacc': 62.1, 'ap': 54.11, 'roc': 62.1, 'f1': 61.79, 'dp': 6.15, 'eo': 18.71, 'ge': 16.39, 'si': 5.28, 'acc_grp': {0: 0.542, 1: 0.669}, 'pos_rate_grp': {0: 0.576, 1: 0.514}, 'g_adv': 0, 'acc_cls': {0: 0.574, 1: 0.668}}
# Data: compas_race | Run: 0 | Base: LR | Model: ThrEO
# Split: 0 | {'acc': 61.19, 'bacc': 60.04, 'ap': 53.3, 'roc': 60.04, 'f1': 59.37, 'dp': 7.52, 'eo': 5.65, 'ge': 25.09, 'si': 5.19, 'acc_grp': {0: 0.643, 1: 0.591}, 'pos_rate_grp': {0: 0.277, 1: 0.352}, 'g_adv': 1, 'acc_cls': {0: 0.772, 1: 0.429}}
# Split: 1 | {'acc': 61.53, 'bacc': 60.5, 'ap': 53.49, 'roc': 60.5, 'f1': 60.07, 'dp': 1.01, 'eo': 2.16, 'ge': 24.01, 'si': 2.81, 'acc_grp': {0: 0.631, 1: 0.605}, 'pos_rate_grp': {0: 0.337, 1: 0.347}, 'g_adv': 1, 'acc_cls': {0: 0.755, 1: 0.455}}
# Split: 2 | {'acc': 64.26, 'bacc': 63.19, 'ap': 55.87, 'roc': 63.19, 'f1': 62.79, 'dp': 3.43, 'eo': 2.67, 'ge': 22.47, 'si': 2.47, 'acc_grp': {0: 0.652, 1: 0.636}, 'pos_rate_grp': {0: 0.316, 1: 0.35}, 'g_adv': 1, 'acc_cls': {0: 0.787, 1: 0.477}}
# Split: 3 | {'acc': 65.53, 'bacc': 64.67, 'ap': 56.99, 'roc': 64.67, 'f1': 64.5, 'dp': 1.49, 'eo': 3.28, 'ge': 20.7, 'si': 4.85, 'acc_grp': {0: 0.664, 1: 0.65}, 'pos_rate_grp': {0: 0.355, 1: 0.37}, 'g_adv': 1, 'acc_cls': {0: 0.772, 1: 0.521}}
# Split: 4 | {'acc': 61.28, 'bacc': 60.19, 'ap': 53.37, 'roc': 60.19, 'f1': 59.62, 'dp': 0.97, 'eo': 4.6, 'ge': 24.67, 'si': 4.85, 'acc_grp': {0: 0.64, 1: 0.595}, 'pos_rate_grp': {0: 0.337, 1: 0.327}, 'g_adv': 0, 'acc_cls': {0: 0.764, 1: 0.44}}
# Data: compas_race | Run: 0 | Base: LR | Model: RedDP
# Split: 0 | {'acc': 57.7, 'bacc': 56.42, 'ap': 50.55, 'roc': 56.42, 'f1': 55.38, 'dp': 11.21, 'eo': 14.31, 'ge': 28.2, 'si': 0.0, 'acc_grp': {0: 0.587, 1: 0.57}, 'pos_rate_grp': {0: 0.238, 1: 0.35}, 'g_adv': 1, 'acc_cls': {0: 0.754, 1: 0.374}}
# Split: 1 | {'acc': 62.3, 'bacc': 60.98, 'ap': 54.15, 'roc': 60.98, 'f1': 60.13, 'dp': 5.43, 'eo': 2.91, 'ge': 25.06, 'si': 0.0, 'acc_grp': {0: 0.652, 1: 0.603}, 'pos_rate_grp': {0: 0.269, 1: 0.323}, 'g_adv': 1, 'acc_cls': {0: 0.801, 1: 0.419}}
# Split: 2 | {'acc': 62.3, 'bacc': 60.76, 'ap': 54.19, 'roc': 60.76, 'f1': 59.44, 'dp': 5.37, 'eo': 8.19, 'ge': 26.21, 'si': 0.0, 'acc_grp': {0: 0.629, 1: 0.619}, 'pos_rate_grp': {0: 0.237, 1: 0.29}, 'g_adv': 1, 'acc_cls': {0: 0.831, 1: 0.384}}
# Split: 3 | {'acc': 58.55, 'bacc': 57.02, 'ap': 51.01, 'roc': 57.02, 'f1': 55.5, 'dp': 1.77, 'eo': 11.65, 'ge': 28.97, 'si': 0.0, 'acc_grp': {0: 0.557, 1: 0.604}, 'pos_rate_grp': {0: 0.262, 1: 0.279}, 'g_adv': 1, 'acc_cls': {0: 0.793, 1: 0.347}}
# Split: 4 | {'acc': 60.26, 'bacc': 58.7, 'ap': 52.5, 'roc': 58.7, 'f1': 57.11, 'dp': 5.8, 'eo': 9.65, 'ge': 28.06, 'si': 0.0, 'acc_grp': {0: 0.608, 1: 0.599}, 'pos_rate_grp': {0: 0.228, 1: 0.286}, 'g_adv': 1, 'acc_cls': {0: 0.818, 1: 0.356}}
# Data: compas_race | Run: 0 | Base: LR | Model: RedEO
# Split: 0 | {'acc': 56.94, 'bacc': 56.11, 'ap': 50.21, 'roc': 56.11, 'f1': 55.79, 'dp': 7.52, 'eo': 12.58, 'ge': 25.68, 'si': 0.0, 'acc_grp': {0: 0.557, 1: 0.577}, 'pos_rate_grp': {0: 0.328, 1: 0.403}, 'g_adv': 1, 'acc_cls': {0: 0.684, 1: 0.438}}
# Split: 1 | {'acc': 65.87, 'bacc': 64.72, 'ap': 57.45, 'roc': 64.72, 'f1': 64.28, 'dp': 16.56, 'eo': 13.84, 'ge': 21.81, 'si': 0.0, 'acc_grp': {0: 0.689, 1: 0.639}, 'pos_rate_grp': {0: 0.224, 1: 0.39}, 'g_adv': 1, 'acc_cls': {0: 0.814, 1: 0.481}}
# Split: 2 | {'acc': 63.74, 'bacc': 62.5, 'ap': 55.45, 'roc': 62.5, 'f1': 61.83, 'dp': 6.63, 'eo': 9.14, 'ge': 23.7, 'si': 0.0, 'acc_grp': {0: 0.638, 1: 0.637}, 'pos_rate_grp': {0: 0.271, 1: 0.337}, 'g_adv': 1, 'acc_cls': {0: 0.806, 1: 0.444}}
# Split: 3 | {'acc': 55.91, 'bacc': 54.96, 'ap': 49.39, 'roc': 54.96, 'f1': 54.5, 'dp': 2.7, 'eo': 12.88, 'ge': 26.93, 'si': 0.0, 'acc_grp': {0: 0.517, 1: 0.587}, 'pos_rate_grp': {0: 0.374, 1: 0.348}, 'g_adv': 0, 'acc_cls': {0: 0.688, 1: 0.411}}
# Split: 4 | {'acc': 65.02, 'bacc': 65.27, 'ap': 56.59, 'roc': 65.27, 'f1': 65.02, 'dp': 18.48, 'eo': 18.45, 'ge': 15.39, 'si': 0.0, 'acc_grp': {0: 0.638, 1: 0.659}, 'pos_rate_grp': {0: 0.416, 1: 0.601}, 'g_adv': 1, 'acc_cls': {0: 0.616, 1: 0.69}}
# Data: compas_race | Run: 0 | Base: LR | Model: RW
# Split: 0 | {'acc': 65.79, 'bacc': 64.74, 'ap': 57.43, 'roc': 64.74, 'f1': 64.36, 'dp': 31.49, 'eo': 31.99, 'ge': 21.57, 'si': 7.4, 'acc_grp': {0: 0.681, 1: 0.643}, 'pos_rate_grp': {0: 0.145, 1: 0.46}, 'g_adv': 1, 'acc_cls': {0: 0.804, 1: 0.491}}
# Split: 1 | {'acc': 66.47, 'bacc': 65.54, 'ap': 57.91, 'roc': 65.54, 'f1': 65.35, 'dp': 23.58, 'eo': 24.0, 'ge': 20.42, 'si': 5.53, 'acc_grp': {0: 0.678, 1: 0.656}, 'pos_rate_grp': {0: 0.213, 1: 0.449}, 'g_adv': 1, 'acc_cls': {0: 0.79, 1: 0.521}}
# Split: 2 | {'acc': 69.53, 'bacc': 68.36, 'ap': 61.34, 'roc': 68.36, 'f1': 68.03, 'dp': 20.9, 'eo': 26.98, 'ge': 19.48, 'si': 4.68, 'acc_grp': {0: 0.678, 1: 0.707}, 'pos_rate_grp': {0: 0.192, 1: 0.401}, 'g_adv': 1, 'acc_cls': {0: 0.854, 1: 0.514}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 112>()
#     109 n_runs = 1
#     110 n_split = 5
# --> 112 df_res = run_baseline_exp(dataset_zoo, base_model_zoo, model_zoo, n_splits=n_split, n_runs=n_runs, random_state=seed, verbose=True)
#
# Input In [7], in run_baseline_exp(dataset_zoo, base_model_zoo, model_zoo, n_splits, n_runs, random_state, verbose)
#      49 clf = model(
#      50     estimator=base_model,
#      51     random_state=rand_seed,
#      52     **model_kwargs,
#      53 )
#      54 try:
# ---> 55     clf.fit(X_train, y_train)
#      56 except Exception as e:
#      57     # print (f"Error: {e}")
#      58     clf.fit(X_train, y_train, sensitive_features=s_train)
#
# File ~/Research/FairEdit/baselines/reweighting.py:233, in ReweightClassifier.fit(self, X_train, y_train)
#     231 def fit(self, X_train, y_train):
#     232     preprocessor = Reweighing(prot_attr=0)
# --> 233     _, sample_weight = preprocessor.fit_transform(pd.DataFrame(X_train), y_train)
#     234     self.estimator.fit(X_train, y_train, sample_weight=sample_weight)
#     235     return self
#
# File ~/Research/FairEdit/baselines/reweighting.py:91, in Reweighing.fit_transform(self, X, y, sample_weight)
#      89 for i, g in enumerate(self.groups_):
#      90     for j, c in enumerate(self.classes_):
# ---> 91         g_and_c = (groups == g) & (y == c)
#      92         if np.any(g_and_c):
#      93             W_gc = N_(groups == g) * N_(y == c) / (N * N_(g_and_c))
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6694, in Index._cmp_method(self, other, op)
#    6692 else:
#    6693     with np.errstate(all="ignore"):
# -> 6694         result = ops.comparison_op(self._values, other, op)
#    6696 return result
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:282, in comparison_op(left, right, op)
#     278 elif is_numeric_v_string_like(lvalues, rvalues):
#     279     # GH#36377 going through the numexpr path would incorrectly raise
#     280     return invalid_comparison(lvalues, rvalues, op)
# --> 282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
#     283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/common.py:188, in is_object_dtype(arr_or_dtype)
#     161 def is_object_dtype(arr_or_dtype) -> bool:
#     162     """
#     163     Check whether an array-like or dtype is of the object dtype.
#     164
#    (...)
#     186     False
#     187     """
# --> 188     return _is_dtype_type(arr_or_dtype, classes(np.object_))
#
# KeyboardInterrupt:

# %%
def plot_scatter_xy_tradeoff(
        df, x, y, group_key, style, 
        ax=None, title=None, errorbar=False, 
        **kwargs
):
    assert x in df.columns and y in df.columns
    assert group_key in df.columns and style in df.columns
    df_plot = df.groupby([group_key, style]).agg({x: ['mean', 'std'], y: ['mean', 'std']}).reset_index()

    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    for style_val in df_plot[style].unique():
        df_subplot = df_plot[df_plot[style] == style_val]
        x_mean, x_std = df_subplot[x]['mean'], df_subplot[x]['std']
        y_mean, y_std = df_subplot[y]['mean'], df_subplot[y]['std']
        
        ax.scatter(x_mean, y_mean, label=style_val, marker="o", s=50)
        if errorbar:
            ax.errorbar(
                x=x_mean, y=y_mean, 
                xerr=x_std, yerr=y_std, 
                ecolor='k', fmt='none', alpha=0.5,
                # capthick=2, capsize=5, 
            )
        ax.set(
            xlabel=x.upper(),
            ylabel=y.upper(),
        )
        ax.legend()
    return ax

def plot_xy_group_scatter_tradeoff(
        df, xs, ys, group_key, style,
        subfig_size=(3, 3), **kwargs
):
    n_x, n_y = len(xs), len(ys)
    h_ax, w_ax = subfig_size
    
    # one plot for one dataset
    dataset_unique = df['dataset'].unique()

    for data_name in dataset_unique:
        df_data = df[df['dataset'] == data_name]
        fig, axs = plt.subplots(n_y, n_x, figsize=(w_ax*n_x, h_ax*n_y))
        for i, x in enumerate(xs):
            for j, y in enumerate(ys):
                ax = plot_scatter_xy_tradeoff(
                    df_data, x, y, group_key, style, ax=axs[j, i], title=None, **kwargs
                )
        plt.suptitle(f"Dataset: {data_name}")
        plt.tight_layout()
        plt.show()


df_res['n_edit'] = 0
plot_xy_group_scatter_tradeoff(
    df_res, xs=['si', 'ge', 'dp', 'eo'], ys=['acc', 'bacc'], 
    group_key='n_edit', style='method', errorbar=True,
    subfig_size=(4, 4)
)

# %%
df_res[df_res['method'] == 'AdaF1']

# %%
file_name = f'./res_cache/baseline_clf{list(base_model_zoo.keys())}_data{list(dataset_zoo.keys())}_seed{seed}_split{n_split}.csv'
df_res.to_csv(file_name, index=False)

# df_res.to_csv(f'./res_cache/baseline_{dataname}_{s_attr}_seed{seed}_split{n_split}.csv', index=False))
